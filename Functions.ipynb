# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoic', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

def DocReg(doc):
    num = input('Введите номер документа: \n')
    flag = False
    for key in doc:
        if num in key.values():
            flag = True
            print(key.get('name'))
    if not(flag):
        print('Документ не найден в базе')
    
def NumOnShelf(direct):
    num = input('Введите номер документа: \n')
    flag = False
    for k, v in direct.items():
        if num in v:
            flag = True
            print('Документ хранится на полке:',int(k))
    if not(flag):
        print('Документ не найден в базе')
        
def polka(num,direct):
    for k, v in direct.items():
        if num in v:
            result = k
    return result

def AllInfo(doc, direct):
    for element in doc:
        print ('№:',element.get('number'), ' тип:', element.get('type'), ' владелец:', element.get('name'), 
               ' полка хранения:', polka(element.get('number'),directories))
        
def NewShelf(direct):     
    num = input('Введите номер полки: \n')
    if num in direct.keys():
        print('Такая полка уже существует. Текущий перечень полок: ',end="")
        for i in direct.keys():
            print(i,end=" ")
    else:
        direct[num] = []
        print('Полка добавлена. Текущий перечень полок: ',end="")
        for i in direct.keys():
            print(i,end=" ")

def DeleteShelf(direct): 
    num = input('Введите номер полки: \n')
    if num in direct.keys():
        if len(direct[num]) != 0:
            print('На полке есть документы, удалите их перед удалением полки. Текущий перечень полок:',end="")
            for i in direct.keys():
                print(i,end=" ")
        else:
            del direct[num]
            print('Полка удалена. Текущий перечень полок:',end="")
            for i in direct.keys():
                print(i,end=" ")
    else:
        print('Такой полки не существует. Текущий перечень полок:',end="")
        for i in direct.keys():
            print(i,end=" ")
            
def processing():
    command = '0'
    while command != 'q':
        command = input('Введите команду:\n')
        if command == 'p':
            DocReg(documents)
        if command == 's':
            NumOnShelf(directories)
        if command == 'l':
            AllInfo(documents,directories)
        if command == 'as':
            NewShelf(directories)
        if command == 'ds':
            DeleteShelf(directories)
processing()
# Out:
# Введите команду:
# as
# Введите номер полки:
# 4
# Полка добавлена. Текущий перечень полок: 1 2 3 4 Введите команду:
# l
# №: 2207 876234  тип: passport  владелец: Василий Гупкин  полка хранения: 1
# №: 11-2  тип: invoic  владелец: Геннадий Покемонов  полка хранения: 1
# №: 10006  тип: insurance  владелец: Аристарх Павлов  полка хранения: 2
# Введите команду:
# q
